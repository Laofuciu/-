# %% [markdown]
# > 🌟 如果你觉得 ChatTTS 和 ChatTTS_colab 项目对你有帮助，请访问以下链接给它们点个星星吧！🌟
#
# - [ChatTTS 项目](https://github.com/2noise/ChatTTS)
#
# - [ChatTTS_colab 项目](https://github.com/6drf21e/ChatTTS_colab)
#
# 感谢你的支持！
#
# # 运行方法
#
# - 点击菜单栏的--代码执行程序--全部运行即可
# - 执行后在下方的日志中找到类似
#
#   Running on public URL: https://**************.gradio.live  <-这个就是可以访问的公网地址
#
# 安装包的时候提示要重启 请点**"否"**

# %%
# !git clone -q https://github.com/6drf21e/ChatTTS_colab
# %cd ChatTTS_colab
# !git clone -q https://github.com/2noise/ChatTTS
# %cd ChatTTS
# !git checkout -q e6412b1
# %cd ..
# !mv ChatTTS abc
# !mv abc/* /content/ChatTTS_colab/
# !pip install -q omegaconf vocos vector_quantize_pytorch gradio cn2an pypinyin openai jieba WeTextProcessing python-dotenv
# 启动 Gradio 有公网地址
# !python webui_mix.py --share
# Out:
# /content/ChatTTS_colab
# /content/ChatTTS_colab/ChatTTS
# /content/ChatTTS_colab
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 58.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 834.7/834.7 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 87.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 200.8 kB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for encodec (setup.py) ... done
# 2025-03-21 14:30:34.142201: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742567434.372955    1019 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742567434.437145    1019 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 14:30:34.988389: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading ChatTTS model...
# INFO:ChatTTS.core:Download from HF: https://huggingface.co/2Noise/ChatTTS
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# spk_stat.pt: 100% 4.26k/4.26k [00:00<00:00, 23.3MB/s]
#
# Decoder.pt:   0% 0.00/104M [00:00<?, ?B/s]
#
# tokenizer.pt: 100% 337k/337k [00:00<00:00, 14.4MB/s]
#
#
# Vocos.pt:   0% 0.00/54.4M [00:00<?, ?B/s]
#
#
# DVAE_full.pt:   0% 0.00/60.4M [00:00<?, ?B/s]
#
#
#
# GPT.pt:   0% 0.00/901M [00:00<?, ?B/s]
#
#
#
#
# DVAE.pt:   0% 0.00/27.7M [00:00<?, ?B/s]
#
#
#
#
#
# decoder.yaml: 100% 117/117 [00:00<00:00, 858kB/s]
#
# Decoder.pt:  10% 10.5M/104M [00:00<00:00, 100MB/s]
#
#
#
#
#
# dvae.yaml: 100% 143/143 [00:00<00:00, 651kB/s]
#
#
# Vocos.pt:  19% 10.5M/54.4M [00:00<00:00, 68.6MB/s]
#
#
#
# GPT.pt:   1% 10.5M/901M [00:00<00:14, 60.1MB/s]
#
#
#
#
# DVAE.pt:  38% 10.5M/27.7M [00:00<00:00, 61.0MB/s]
#
#
#
#
#
# path.yaml: 100% 309/309 [00:00<00:00, 2.06MB/s]
#
#
#
#
#
#
# gpt.yaml: 100% 346/346 [00:00<00:00, 2.76MB/s]
#
# Decoder.pt:  20% 21.0M/104M [00:00<00:00, 85.9MB/s]
#
#
# DVAE_full.pt:  17% 10.5M/60.4M [00:00<00:00, 52.2MB/s]
#
#
#
#
#
# vocos.yaml: 100% 460/460 [00:00<00:00, 3.28MB/s]
#
#
# Vocos.pt:  39% 21.0M/54.4M [00:00<00:00, 71.4MB/s]
#
#
#
# GPT.pt:   2% 21.0M/901M [00:00<00:12, 69.1MB/s]
#
#
#
#
# DVAE.pt:  76% 21.0M/27.7M [00:00<00:00, 62.9MB/s]
#
#
# DVAE_full.pt:  35% 21.0M/60.4M [00:00<00:00, 58.5MB/s]
# Decoder.pt:  30% 31.5M/104M [00:00<00:00, 72.6MB/s]
#
# Vocos.pt:  58% 31.5M/54.4M [00:00<00:00, 82.4MB/s]
#
#
#
# DVAE.pt: 100% 27.7M/27.7M [00:00<00:00, 64.7MB/s]
# Fetching 12 files:   8% 1/12 [00:00<00:07,  1.57it/s]
#
#
# DVAE_full.pt:  52% 31.5M/60.4M [00:00<00:00, 65.4MB/s]
# Decoder.pt:  40% 41.9M/104M [00:00<00:00, 70.6MB/s]
#
# Vocos.pt:  77% 41.9M/54.4M [00:00<00:00, 73.4MB/s]
#
#
#
# GPT.pt:   5% 41.9M/901M [00:00<00:11, 75.2MB/s]
#
#
# DVAE_full.pt:  69% 41.9M/60.4M [00:00<00:00, 69.2MB/s]
# Decoder.pt:  51% 52.4M/104M [00:00<00:00, 72.7MB/s]
#
# Vocos.pt:  96% 52.4M/54.4M [00:00<00:00, 80.0MB/s]
#
#
#
# Vocos.pt: 100% 54.4M/54.4M [00:00<00:00, 72.6MB/s]
#
#
#
# DVAE_full.pt:  87% 52.4M/60.4M [00:00<00:00, 72.6MB/s]
#
#
#
# DVAE_full.pt: 100% 60.4M/60.4M [00:00<00:00, 71.0MB/s]
# Fetching 12 files:  17% 2/12 [00:01<00:05,  1.99it/s]
# Decoder.pt:  71% 73.4M/104M [00:00<00:00, 85.4MB/s]
#
#
#
# GPT.pt:  10% 94.4M/901M [00:00<00:06, 118MB/s]
# Decoder.pt: 100% 104M/104M [00:01<00:00, 95.2MB/s]
# Fetching 12 files:  25% 3/12 [00:01<00:03,  2.76it/s]
#
#
#
# GPT.pt:  13% 115M/901M [00:01<00:05, 140MB/s]
#
#
#
# GPT.pt:  16% 147M/901M [00:01<00:04, 168MB/s]
#
#
#
# GPT.pt:  20% 178M/901M [00:01<00:03, 191MB/s]
#
#
#
# GPT.pt:  23% 210M/901M [00:01<00:03, 209MB/s]
#
#
#
# GPT.pt:  27% 241M/901M [00:01<00:02, 222MB/s]
#
#
#
# GPT.pt:  30% 273M/901M [00:01<00:02, 230MB/s]
#
#
#
# GPT.pt:  34% 304M/901M [00:01<00:02, 235MB/s]
#
#
#
# GPT.pt:  37% 336M/901M [00:01<00:02, 246MB/s]
#
#
#
# GPT.pt:  41% 367M/901M [00:02<00:02, 248MB/s]
#
#
#
# GPT.pt:  44% 398M/901M [00:02<00:02, 245MB/s]
#
#
#
# GPT.pt:  48% 430M/901M [00:02<00:02, 235MB/s]
#
#
#
# GPT.pt:  51% 461M/901M [00:02<00:01, 229MB/s]
#
#
#
# GPT.pt:  55% 493M/901M [00:02<00:01, 228MB/s]
#
#
#
# GPT.pt:  58% 524M/901M [00:02<00:01, 229MB/s]
#
#
#
# GPT.pt:  62% 556M/901M [00:02<00:01, 230MB/s]
#
#
#
# GPT.pt:  65% 587M/901M [00:03<00:01, 225MB/s]
#
#
#
# GPT.pt:  69% 619M/901M [00:03<00:01, 231MB/s]
#
#
#
# GPT.pt:  72% 650M/901M [00:03<00:01, 232MB/s]
#
#
#
# GPT.pt:  76% 682M/901M [00:03<00:01, 192MB/s]
#
#
#
# GPT.pt:  79% 713M/901M [00:03<00:00, 205MB/s]
#
#
#
# GPT.pt:  83% 744M/901M [00:04<00:01, 81.4MB/s]
#
#
#
# GPT.pt:  86% 776M/901M [00:04<00:01, 103MB/s]
#
#
#
# GPT.pt:  90% 807M/901M [00:04<00:00, 125MB/s]
#
#
#
# GPT.pt:  93% 839M/901M [00:04<00:00, 146MB/s]
#
#
#
# GPT.pt:  97% 870M/901M [00:05<00:00, 165MB/s]
#
#
#
# GPT.pt: 100% 901M/901M [00:05<00:00, 171MB/s]
# Fetching 12 files: 100% 12/12 [00:05<00:00,  2.19it/s]
# INFO:ChatTTS.core:use cuda:0
# INFO:ChatTTS.core:vocos loaded.
# INFO:ChatTTS.core:dvae loaded.
# INFO:ChatTTS.core:gpt loaded.
# INFO:ChatTTS.core:decoder loaded.
# Traceback (most recent call last):
#   File "/content/ChatTTS_colab/webui_mix.py", line 46, in <module>
#     chat = load_chat_tts_model(source=args.source, local_path=args.local_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ChatTTS_colab/tts_model.py", line 25, in load_chat_tts_model
#     chat.load_models(source=source, force_redownload=force_redownload, custom_path=local_path, compile=False)
#   File "/content/ChatTTS_colab/ChatTTS/core.py", line 81, in load_models
#     self._load(**{k: os.path.join(download_path, v) for k, v in OmegaConf.load(os.path.join(download_path, 'config', 'path.yaml')).items()}, **kwargs)
#   File "/content/ChatTTS_colab/ChatTTS/core.py", line 144, in _load
#     tokenizer = torch.load(tokenizer_path, map_location='cpu')
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1470, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL transformers.models.bert.tokenization_bert_fast.BertTokenizerFast was not an allowed global by default. Please use `torch.serialization.add_safe_globals([BertTokenizerFast])` or the `torch.serialization.safe_globals([BertTokenizerFast])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
